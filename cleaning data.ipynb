# %%
import csv
import sys
import pandas as pd

csv.field_size_limit(sys.maxsize)
# Out:
# 9223372036854775807

# %%
from datetime import datetime

def make_date (myDate):
    year = myDate.split("-")
    if int(year[0]) < 2261:
        dt = datetime.strptime(myDate, "%Y-%m-%d 00:00:00")
        return dt
    else:
        print("year too big for Pandas", year[0])
        raise ValueError('Invalid date')

# %%
offender_database = []
first_row = 0
myRange = [11,12]

with open('data/Offender.csv', newline='') as csvfile:
    offender_reader = csv.reader(csvfile, delimiter=',')
    for row in offender_reader:
        if first_row == 0:
            print(row)
            first_row = row
            
        else:
            if len(row) > 16:
                row[13] = row[13] + row[14] + row[15]
                row[14] = row[16]
                row.pop() # remove from row array
                row.pop() # remove from row array
            elif len(row) > 15:
                row[13] = row[13] + row[14]
                row[14] = row[15]
                row.pop() # remove from row array
            try:
                for i in myRange:
                    row[i] = make_date(row[i])
            except:
                continue
            offender_database.append(row)

offenderDS = pd.DataFrame(data=offender_database, columns=first_row)
offenderDS['ReceptionDate'] = pd.to_datetime(offenderDS['ReceptionDate'])
offenderDS.ReceptionDate=offenderDS.ReceptionDate.dt.strftime('%Y')
# Out:
# ['DocNum', 'LastName', 'FirstName', 'MiddleInit', 'Suffix', 'Race', 'Gender', 'HairColor', 'EyeColor', 'Height', 'Weight', 'DOB', 'ReceptionDate', 'CurrentFacility', 'Status']

# %%
#pt = pd.pivot_table(offenderDS, values=["DocNum"], index=["Status"], aggfunc='count', columns=['ReceptionDate'])
pt = pd.pivot_table(offenderDS, values=["DocNum"], index=["ReceptionDate"], aggfunc="count", columns=["Status"])
pt.plot(kind="line",).legend()

# %%
#before you open these files, remove the errant quote on line 191780

alias_database = []
first_row = 0 

with open('data/OffenderAlias.csv', encoding = "ISO-8859-1") as csvfile:
    offender_reader = csv.reader(csvfile, delimiter=',')
    for row in offender_reader:
        if first_row == 0:
            print(row)
            first_row = row
        else:
            if row[2] == "":
                continue # skip lines with no last name
            if len(row) > 7:
                print(row)
                continue # skip these lines or you can edit by hand
            try:
                row[6] = make_date(row[6])
            except:
                continue
            alias_database.append(row)

aliasDS = pd.DataFrame(data=alias_database, columns=first_row)
aliasDS['DOB'] = pd.to_datetime(aliasDS['DOB'])
aliasDS.DOB=aliasDS.DOB.dt.strftime('%Y')
# Out:
# ['Id', 'DOCNum', 'LastName', 'FirstName', 'MiddleInit', 'Suffix', 'DOB']
# ['695541', '188288', 'Conner', 'v', 'George', 'F', '', '1970-11-09 00:00:00']
# ['714115', '232759', 'Ramirez', '', 'Julian', 'R', '', '1961-01-09 00:00:00']
# ['761729', '451319', 'Patron', '', 'Filameno', '', '', '1971-07-05 00:00:00']
# ['774815', '516258', 'Hunter', '', 'Anthony', '', '', '1976-11-11 00:00:00']
# ['795825', '632218', 'Thorpe', '', 'James', 'O', '', '1972-04-07 00:00:00']
# ['796891', '638210', 'Byrum', '', 'Terry', '', '', '1983-12-09 00:00:00']
# ['805044', '683470', 'Aleman', ' Carlos', 'Aberto', '', '', '1983-04-22 00:00:00']
# ['830852', '523423', 'Adams', 'Terrance', ",,1979-05-05 00:00:00\n830853,523428,Mist'Ry,Dawn,B,,1982-01-21 00:00:00\n830854,523477,Reich,John,,,1976-09-04 00:00:00\n830855,523493,Fox,Keith,,,1983-05-27 00:00:00\n830856,523555,Dominic,Dewayne,H,,1980-08-27 00:00:00\n830857,524193,Johnson,Clifford,W,,1985-10-27 00:00:00\n830858,524337,Aldada,Iyad,A,,1971-03-28 00:00:00\n830859,524394,Martin,Anthony,D,,1970-10-17 00:00:00\n830860,524394,Martin,Tony,,,1970-10-14 00:00:00\n830861,524552,Webb,Richard,,,1960-01-03 00:00:00\n830862,524586,Jacks,Zachary,M,,1985-12-19 00:00:00\n830863,524625,Shocklee,Diana,L,,1960-05-19 00:00:00\n830864,524864,Watson,Chad,,,1985-09-09 00:00:00\n830865,525057,Brasell,William,J,,1978-02-15 00:00:00\n830866,525114,Delany,Shane,M,,1986-11-04 00:00:00\n830867,525362,Jones,Teleasha,,,1985-11-04 00:00:00\n830868,525363,Bryce,Justin,,,1984-01-05 00:00:00\n830869,525559,Rodriguez,Marcos,A,,1984-08-14 00:00:00\n830870,525841,Fincannon,Jason,A,,1971-05-07 00:00:00\n830871,526204,Anderson,Robyn,N,,1978-11-20 00:00:00\n830872,526204,Anderson,Robyn,N,,1978-11-30 00:00:00\n830873,526204,Long,Tamika,L,,1976-01-22 00:00:00\n830874,526304,Luman,Timothy,,,1968-12-30 00:00:00\n830875,526871,Hammon,Cordalle,,,1986-06-25 00:00:00\n830876,526871,Hammond,Cordell,,,1986-06-25 00:00:00\n830877,526871,Hamon,Cordalle,D,,1986-06-25 00:00:00\n830878,526974,Martinez,Cesar,J,,1984-03-05 00:00:00\n830879,527255,Shanks,Shawn,,,1974-11-22 00:00:00\n830880,527334,Harrell,Marjorie,K,,1962-11-16 00:00:00\n830881,527421,Beery,Charles,,,1972-03-16 00:00:00\n830882,527546,Shell,Benjamin,P,JR,1963-02-08 00:00:00\n830883,527694,Molina,Michael,K,,1968-05-29 00:00:00\n830884,527927,Gregory,Monte,,,1961-10-16 00:00:00\n830885,527936,McPhail,Kaatherine,D,,1985-04-07 00:00:00\n830886,528166,Louise,Rae,A,,1983-09-03 00:00:00\n830887,528166,Passio,Raeann,,,1983-09-03 00:00:00\n830888,528334,Armstrong,Clint,,,1987-06-30 00:00:00\n830889,528439,Messick,Crystal,,,1985-07-03 00:00:00\n830890,528439,Messick,Crystal,D,,1985-07-03 00:00:00\n830891,528507,Fry,Norman,R,,1969-07-02 00:00:00\n830892,528613,Lawrence,Johnathan,,,1986-09-23 00:00:00\n830893,528613,Martin,Johnatan,D,,1986-09-23 00:00:00\n830894,528908,Johnson,Kristina,P,,1967-12-14 00:00:00\n830895,528911,Smith,Vernelln,,,1968-04-01 00:00:00\n830896,529068,Bingham,Brandon,,,1982-10-18 00:00:00\n830897,529153,Jones,Christopher,D,,1969-09-06 00:00:00\n830898,529180,Gann,Adam,W,,1979-04-04 00:00:00\n830899,529237,Mulhall,Davina,D,,1972-12-17 00:00:00\n830900,529337,Dever,Michael,G,,1981-09-04 00:00:00\n830901,529803,Chump,,,,1987-01-10 00:00:00\n830902,529803,Hopkins,Shawn,,,1987-01-10 00:00:00\n830903,529803,Shon,,,,1987-01-10 00:00:00\n830904,529813,Cole,Lorrie,D,,1963-03-29 00:00:00\n830905,529899,Caldwell,Phillip,G,,1957-12-14 00:00:00\n830906,529966,Day,Larry,M,,1975-10-09 00:00:00\n830907,530152,MacKey,Michael,,,1979-10-23 00:00:00\n830908,530176,Ware,Jesse,R,,1962-06-15 00:00:00\n830909,530354,Mason,Ihsan,,,1974-07-04 00:00:00\n830910,530507,Faure,Miguel,,IV,1971-09-11 00:00:00\n830911,530734,Frederick,Charles,E,JR,1985-09-11 00:00:00\n830912,531077,Smith,Joseph,N,II,1968-08-14 00:00:00\n830913,531078,Martines,Erica,D,,1986-09-26 00:00:00\n830914,531078,Martinez,Erica,,,1986-09-26 00:00:00\n830915,531190,Lopez,Ricardo,,,1986-10-20 00:00:00\n830916,531348,Becerra,Oscar,H,,1987-09-18 00:00:00\n830917,531459,Bricker,Joseph,C,,1957-09-10 00:00:00\n830918,531459,Lamb,Joseph,,,1955-09-10 00:00:00\n830919,531459,Lamb,Ronald,,,1957-09-10 00:00:00\n830920,531701,Edwards,David,Q,,1983-01-05 00:00:00\n830921,531701,Edwards,Steve,,,1983-01-05 00:00:00\n830922,531923,Sole,Kathy,A,,1953-12-04 00:00:00\n830923,531945,Alvadaz,Juan,,,1970-02-08 00:00:00\n830924,531984,Hodge,Danny,,,1986-08-16 00:00:00\n830925,532093,Rodman,Kevin,D,,1976-07-28 00:00:00\n830926,532153,Garrett,Aaron,,,1986-07-01 00:00:00\n830927,532194,Koonce,Bret,E,,1980-11-20 00:00:00\n830928,532205,Stapp,Kenneth,D,,1983-10-14 00:00:00\n830929,532 ...
# ['831749', '583692', 'Jefferson', ' Jr.', 'Randy', 'L', '', '1980-04-23 00:00:00']

# %%
pt = pd.pivot_table(aliasDS, values=["DOCNum"], index=["DOB"], aggfunc="count")
pt.plot(kind="line",).legend()

# %%
exit_database = []
first_row = 0

with open('data/OffenderExit.csv') as csvfile:
    offender_reader = csv.reader(csvfile, delimiter=',')
    for row in offender_reader:
        if first_row == 0:
            print(row)
            first_row = row
        else:
            if len(row) > 3:
                row[2] = row[2] + row[3]
                row.pop()
            elif len(row) > 4:
                print(row)
            exit_database.append(row)

exitDS = pd.DataFrame(data=exit_database, columns=first_row)
exitDS['ExitDate'] = pd.to_datetime(exitDS['ExitDate'])
exitDS.ExitDate=exitDS.ExitDate.dt.strftime('%Y')
# Out:
# ['DOCNum', 'ExitDate', 'ExitReason']

# %%
pt = pd.pivot_table(exitDS, values=["DOCNum"], index=["ExitDate"], aggfunc="count")
pt.plot(kind="line",).legend()

# %%
reception_database = []
first_row = 0

with open('data/OffenderReception.csv') as csvfile:
    offender_reader = csv.reader(csvfile, delimiter=',')
    for row in offender_reader:
        if first_row == 0:
            print(row)
            first_row = row
        else:
            if len(row) > 5:
                row[2] = row[2] + row[3] + row[4]
                row[3] = row[5]
                row.pop()
                row.pop()
            elif len(row) > 4:
                row[2] = row[2] + row[3]
                row[3] = row[4]
                row.pop()
            reception_database.append(row)

recepDS = pd.DataFrame(data=reception_database, columns=first_row)
recepDS['MovementDate'] = pd.to_datetime(recepDS['MovementDate'])
recepDS.MovementDate=recepDS.MovementDate.dt.strftime('%Y')
# Out:
# ['DocNum', 'MovementDate', 'Reason', 'Facility']

# %%
pt = pd.pivot_table(recepDS, values=["DocNum"], index=["MovementDate"], aggfunc="count")
pt.plot(kind="line",).legend()

# %%
sentence_database = []
first_row = 0
myRange = [5, 15, 16]

with open('data/OffenderSentence.csv', encoding = "ISO-8859-1") as csvfile:
    offender_reader = csv.reader(csvfile, delimiter=',')
    for row in offender_reader:
        if first_row == 0:
            print(row)
            first_row = row
        else:
            try:
                for i in myRange:
                    #print(i, row[i])
                    row[i] = make_date(row[i])
            except:
                continue
            sentence_database.append(row)
# Out:
# ['Id', 'DOCNum', 'OrderID', 'ChargeSeq', 'CRFNum', 'ConvictDate', 'Court', 'StatuteCode', 'OffenceDescription', 'OffenceComment', 'SentenceTermCode', 'Years', 'Months', 'Days', 'SentenceTerm', 'StartDate', 'EndDate', 'CountNum', 'OrderCode', 'ConsecutiveToCount', 'ChargeStatus']
# year too big for Pandas 2272
# year too big for Pandas 2984
# year too big for Pandas 2890
# year too big for Pandas 3004
# year too big for Pandas 2861
# year too big for Pandas 2986
# year too big for Pandas 2779
# year too big for Pandas 2779
# year too big for Pandas 2381
# year too big for Pandas 2280
# year too big for Pandas 2280
# year too big for Pandas 2530
# year too big for Pandas 2430
# year too big for Pandas 2680
# year too big for Pandas 2992
# year too big for Pandas 3006
# year too big for Pandas 2973
# year too big for Pandas 2972
# year too big for Pandas 2996
# year too big for Pandas 2996
# year too big for Pandas 2981
# year too big for Pandas 2341
# year too big for Pandas 2341
# year too big for Pandas 2491
# year too big for Pandas 2611
# year too big for Pandas 2761
# year too big for Pandas 2801
# year too big for Pandas 2841
# year too big for Pandas 2881
# year too big for Pandas 2921
# year too big for Pandas 2961
# year too big for Pandas 3001
# year too big for Pandas 3041
# year too big for Pandas 3081
# year too big for Pandas 3121
# year too big for Pandas 3161
# year too big for Pandas 3201
# year too big for Pandas 3501
# year too big for Pandas 3801
# year too big for Pandas 2997
# year too big for Pandas 2992
# year too big for Pandas 2983
# year too big for Pandas 2348
# year too big for Pandas 2952
# year too big for Pandas 2976
# year too big for Pandas 2965
# year too big for Pandas 2673
# year too big for Pandas 2480
# year too big for Pandas 2480
# year too big for Pandas 2540
# year too big for Pandas 2490
# year too big for Pandas 2480
# year too big for Pandas 2895
# year too big for Pandas 2895
# year too big for Pandas 2264
# year too big for Pandas 2264
# year too big for Pandas 3966
# year too big for Pandas 2985
# year too big for Pandas 2985
# year too big for Pandas 2862
# year too big for Pandas 2862
# year too big for Pandas 3056
# year too big for Pandas 2470
# year too big for Pandas 3963
# year too big for Pandas 2377
# year too big for Pandas 2961
# year too big for Pandas 2281
# year too big for Pandas 2399
# year too big for Pandas 3046
# year too big for Pandas 3046
# year too big for Pandas 2311
# year too big for Pandas 2311
# year too big for Pandas 2300
# year too big for Pandas 3025
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3977
# year too big for Pandas 2991
# year too big for Pandas 3973
# year too big for Pandas 3044
# year too big for Pandas 3044
# year too big for Pandas 3044
# year too big for Pandas 3205
# year too big for Pandas 3963
# year too big for Pandas 2911
# year too big for Pandas 2401
# year too big for Pandas 2989
# year too big for Pandas 2992
# year too big for Pandas 2992
# year too big for Pandas 3991
# year too big for Pandas 4990
# year too big for Pandas 5989
# year too big for Pandas 6988
# year too big for Pandas 3961
# year too big for Pandas 3976
# year too big for Pandas 3135
# year too big for Pandas 2990
# year too big for Pandas 2991
# year too big for Pandas 2992
# year too big for Pandas 3035
# year too big for Pandas 3035
# year too big for Pandas 3004
# year too big for Pandas 3004
# year too big for Pandas 3020
# year too big for Pandas 2787
# year too big for Pandas 2895
# year too big for Pandas 2898
# year too big for Pandas 2753
# year too big for Pandas 2995
# year too big for Pandas 2995
# year too big for Pandas 2995
# year too big for Pandas 2995
# year too big for Pandas 2995
# year too big for Pandas 2995
# year too big for Pandas 2995
# year too big for Pandas 2995
# year too big for Pandas 2993
# year too big for Pandas 2995
# year too big for Pandas 2889
# year too big for Pandas 3972
# year too big for Pandas 3036
# year too big for Pandas 3973
# year too big for Pandas 3046
# year too big for Pandas 3046
# year too big for Pandas 3976
# year too big for Pandas 2799
# year too big for Pandas 2799
# year too big for Pandas 3742
# year too big for Pandas 5743
# year too big for Pandas 7745
# year too big for Pandas 6988
# year too big for Pandas 8074
# year too big for Pandas 8576
# year too big for Pandas 3742
# year too big for Pandas 3039
# year too big for Pandas 3039
# year too big for Pandas 2799
# year too big for Pandas 2799
# year too big for Pandas 2799
# year too big for Pandas 2799
# year too big for Pandas 2301
# year too big for Pandas 2301
# year too big for Pandas 2401
# year too big for Pandas 2501
# year too big for Pandas 2599
# year too big for Pandas 2649
# year too big for Pandas 2998
# year too big for Pandas 2998
# year too big for Pandas 2998
# year too big for Pandas 3997
# year too big for Pandas 3978
# year too big for Pandas 2299
# year too big for Pandas 2299
# year too big for Pandas 2299
# year too big for Pandas 2717
# year too big for Pandas 2721
# year too big for Pandas 2887
# year too big for Pandas 2792
# year too big for Pandas 3980
# year too big for Pandas 3980
# year too big for Pandas 2908
# year too big for Pandas 2908
# year too big for Pandas 2264
# year too big for Pandas 2264
# year too big for Pandas 2264
# year too big for Pandas 2264
# year too big for Pandas 2309
# year too big for Pandas 2309
# year too big for Pandas 2354
# year too big for Pandas 2354
# year too big for Pandas 2354
# year too big for Pandas 2399
# year too big for Pandas 2995
# year too big for Pandas 3977
# year too big for Pandas 3978
# year too big for Pandas 3112
# year too big for Pandas 2995
# year too big for Pandas 2995
# year too big for Pandas 3495
# year too big for Pandas 5245
# year too big for Pandas 6244
# year too big for Pandas 7243
# year too big for Pandas 8242
# year too big for Pandas 8737
# year too big for Pandas 8757
# year too big for Pandas 8777
# year too big for Pandas 8817
# year too big for Pandas 8837
# year too big for Pandas 9337
# year too big for Pandas 2909
# year too big for Pandas 2426
# year too big for Pandas 2426
# year too big for Pandas 2426
# year too big for Pandas 2426
# year too big for Pandas 2292
# year too big for Pandas 2292
# year too big for Pandas 2367
# year too big for Pandas 2382
# year too big for Pandas 2402
# year too big for Pandas 3976
# year too big for Pandas 2274
# year too big for Pandas 2806
# year too big for Pandas 2804
# year too big for Pandas 2900
# year too big for Pandas 2900
# year too big for Pandas 2886
# year too big for Pandas 2997
# year too big for Pandas 2998
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3006
# year too big for Pandas 2994
# year too big for Pandas 2996
# year too big for Pandas 2997
# year too big for Pandas 2960
# year too big for Pandas 3032
# year too big for Pandas 3032
# year too big for Pandas 2401
# year too big for Pandas 2998
# year too big for Pandas 3023
# year too big for Pandas 3023
# year too big for Pandas 3023
# year too big for Pandas 3023
# year too big for Pandas 3023
# year too big for Pandas 3023
# year too big for Pandas 3027
# year too big for Pandas 2275
# year too big for Pandas 2275
# year too big for Pandas 2295
# year too big for Pandas 2315
# year too big for Pandas 2335
# year too big for Pandas 2355
# year too big for Pandas 2375
# year too big for Pandas 2395
# year too big for Pandas 2415
# year too big for Pandas 2435
# year too big for Pandas 2455
# year too big for Pandas 2475
# year too big for Pandas 2495
# year too big for Pandas 2515
# year too big for Pandas 2535
# year too big for Pandas 2555
# year too big for Pandas 2575
# year too big for Pandas 2595
# year too big for Pandas 2615
# year too big for Pandas 2635
# year too big for Pandas 2572
# year too big for Pandas 2572
# year too big for Pandas 2572
# year too big for Pandas 2672
# year too big for Pandas 2672
# year too big for Pandas 3272
# year too big for Pandas 2295
# year too big for Pandas 2340
# year too big for Pandas 2906
# year too big for Pandas 3001
# year too big for Pandas 3034
# year too big for Pandas 3009
# year too big for Pandas 3005
# year too big for Pandas 3005
# year too big for Pandas 3005
# year too big for Pandas 3005
# year too big for Pandas 3030
# year too big for Pandas 2479
# year too big for Pandas 2478
# year too big for Pandas 2478
# year too big for Pandas 2473
# year too big for Pandas 3049
# year too big for Pandas 3049
# year too big for Pandas 3049
# year too big for Pandas 3049
# year too big for Pandas 3049
# year too big for Pandas 3049
# year too big for Pandas 3049
# year too big for Pandas 3049
# year too big for Pandas 3040
# year too big for Pandas 9999
# year too big for Pandas 3009
# year too big for Pandas 3120
# year too big for Pandas 3120
# year too big for Pandas 2991
# year too big for Pandas 2290
# year too big for Pandas 2290
# year too big for Pandas 2295
# year too big for Pandas 2320
# year too big for Pandas 2330
# year too big for Pandas 2400
# year too big for Pandas 2350
# year too big for Pandas 2400
# year too big for Pandas 2355
# year too big for Pandas 2410
# year too big for Pandas 2365
# year too big for Pandas 2430
# year too big for Pandas 2385
# year too big for Pandas 2430
# year too big for Pandas 2395
# year too big for Pandas 2440
# year too big for Pandas 2405
# year too big for Pandas 2450
# year too big for Pandas 2425
# year too big for Pandas 2470
# year too big for Pandas 2445
# year too big for Pandas 2490
# year too big for Pandas 2465
# year too big for Pandas 2510
# year too big for Pandas 2475
# year too big for Pandas 2530
# year too big for Pandas 2495
# year too big for Pandas 2545
# year too big for Pandas 2505
# year too big for Pandas 2565
# year too big for Pandas 2525
# year too big for Pandas 2585
# year too big for Pandas 2575
# year too big for Pandas 2595
# year too big for Pandas 2725
# year too big for Pandas 2615
# year too big for Pandas 2745
# year too big for Pandas 2635
# year too big for Pandas 2765
# year too big for Pandas 2655
# year too big for Pandas 2785
# year too big for Pandas 2675
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 3000
# year too big for Pandas 3006
# year too big for Pandas 3006
# year too big for Pandas 3022
# year too big for Pandas 3022
# year too big for Pandas 3000
# year too big for Pandas 9999
# year too big for Pandas 3094
# year too big for Pandas 2377
# year too big for Pandas 3035
# year too big for Pandas 2569
# year too big for Pandas 2320
# year too big for Pandas 2320
# year too big for Pandas 2419
# year too big for Pandas 2518
# year too big for Pandas 2617
# year too big for Pandas 2637
# year too big for Pandas 2657
# year too big for Pandas 2677
# year too big for Pandas 2697
# year too big for Pandas 2717
# year too big for Pandas 2266
# year too big for Pandas 2265
# year too big for Pandas 2265
# year too big for Pandas 2265
# year too big for Pandas 2265
# year too big for Pandas 2266
# year too big for Pandas 2266
# year too big for Pandas 2276
# year too big for Pandas 2276
# year too big for Pandas 3023
# year too big for Pandas 3056
# year too big for Pandas 3041
# year too big for Pandas 3024
# year too big for Pandas 2401
# year too big for Pandas 2401
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 2264
# year too big for Pandas 2264
# year too big for Pandas 2279
# year too big for Pandas 2294
# year too big for Pandas 2309
# year too big for Pandas 2324
# year too big for Pandas 2339
# year too big for Pandas 2349
# year too big for Pandas 2359
# year too big for Pandas 2369
# year too big for Pandas 2379
# year too big for Pandas 2389
# year too big for Pandas 2399
# year too big for Pandas 2409
# year too big for Pandas 2419
# year too big for Pandas 2429
# year too big for Pandas 2439
# year too big for Pandas 2449
# year too big for Pandas 2464
# year too big for Pandas 2479
# year too big for Pandas 2494
# year too big for Pandas 2509
# year too big for Pandas 2524
# year too big for Pandas 2539
# year too big for Pandas 2554
# year too big for Pandas 2569
# year too big for Pandas 2584
# year too big for Pandas 2599
# year too big for Pandas 2614
# year too big for Pandas 2619
# year too big for Pandas 2634
# year too big for Pandas 2644
# year too big for Pandas 3035
# year too big for Pandas 3035
# year too big for Pandas 3035
# year too big for Pandas 3045
# year too big for Pandas 3033
# year too big for Pandas 3033
# year too big for Pandas 3033
# year too big for Pandas 3033
# year too big for Pandas 3033
# year too big for Pandas 3033
# year too big for Pandas 3033
# year too big for Pandas 2294
# year too big for Pandas 2997
# year too big for Pandas 2997
# year too big for Pandas 3997
# year too big for Pandas 4997
# year too big for Pandas 5997
# year too big for Pandas 6997
# year too big for Pandas 7997
# year too big for Pandas 8997
# year too big for Pandas 8993
# year too big for Pandas 9013
# year too big for Pandas 3024
# year too big for Pandas 3024
# year too big for Pandas 3017
# year too big for Pandas 3013
# year too big for Pandas 3047
# year too big for Pandas 2352
# year too big for Pandas 3107
# year too big for Pandas 3037
# year too big for Pandas 2477
# year too big for Pandas 2477
# year too big for Pandas 2477
# year too big for Pandas 2877
# year too big for Pandas 2877
# year too big for Pandas 3277
# year too big for Pandas 3277
# year too big for Pandas 3677
# year too big for Pandas 3677
# year too big for Pandas 4077
# year too big for Pandas 4077
# year too big for Pandas 4477
# year too big for Pandas 4477
# year too big for Pandas 4877
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3004
# year too big for Pandas 3045
# year too big for Pandas 3009
# year too big for Pandas 2278
# year too big for Pandas 2278
# year too big for Pandas 2298
# year too big for Pandas 2318
# year too big for Pandas 2418
# year too big for Pandas 2438
# year too big for Pandas 2458
# year too big for Pandas 2478
# year too big for Pandas 2498
# year too big for Pandas 2989
# year too big for Pandas 2989
# year too big for Pandas 2985
# year too big for Pandas 2985
# year too big for Pandas 2985
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3068
# year too big for Pandas 3024
# year too big for Pandas 3024
# year too big for Pandas 3024
# year too big for Pandas 3024
# year too big for Pandas 2502
# year too big for Pandas 2502
# year too big for Pandas 3002
# year too big for Pandas 3502
# year too big for Pandas 4002
# year too big for Pandas 4502
# year too big for Pandas 5002
# year too big for Pandas 5502
# year too big for Pandas 6002
# year too big for Pandas 6502
# year too big for Pandas 7002
# year too big for Pandas 7502
# year too big for Pandas 8002
# year too big for Pandas 8502
# year too big for Pandas 9002
# year too big for Pandas 9493
# year too big for Pandas 2276
# year too big for Pandas 2276
# year too big for Pandas 2476
# year too big for Pandas 2496
# year too big for Pandas 2516
# year too big for Pandas 2536
# year too big for Pandas 2556
# year too big for Pandas 2576
# year too big for Pandas 3044
# year too big for Pandas 3026
# year too big for Pandas 2728
# year too big for Pandas 3040
# year too big for Pandas 3003
# year too big for Pandas 3003
# year too big for Pandas 3003
# year too big for Pandas 3030
# year too big for Pandas 2306
# year too big for Pandas 3039
# year too big for Pandas 2332
# year too big for Pandas 3052
# year too big for Pandas 3045
# year too big for Pandas 3024
# year too big for Pandas 2783
# year too big for Pandas 2783
# year too big for Pandas 3563
# year too big for Pandas 4343
# year too big for Pandas 3060
# year too big for Pandas 3060
# year too big for Pandas 3038
# year too big for Pandas 3038
# year too big for Pandas 3029
# year too big for Pandas 3029
# year too big for Pandas 3041
# year too big for Pandas 3041
# year too big for Pandas 3014
# year too big for Pandas 4118
# year too big for Pandas 2265
# year too big for Pandas 2265
# year too big for Pandas 2290
# year too big for Pandas 2315
# year too big for Pandas 2320
# year too big for Pandas 2325
# year too big for Pandas 2330
# year too big for Pandas 2430
# year too big for Pandas 2530
# year too big for Pandas 2630
# year too big for Pandas 2640
# year too big for Pandas 2650
# year too big for Pandas 2680
# year too big for Pandas 2700
# year too big for Pandas 2725
# year too big for Pandas 2730
# year too big for Pandas 2735
# year too big for Pandas 2745
# year too big for Pandas 2755
# year too big for Pandas 2765
# year too big for Pandas 2770
# year too big for Pandas 3036
# year too big for Pandas 3045
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 3039
# year too big for Pandas 3037
# year too big for Pandas 3037
# year too big for Pandas 3037
# year too big for Pandas 3029
# year too big for Pandas 3041
# year too big for Pandas 3021
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3032
# year too big for Pandas 3057
# year too big for Pandas 3011
# year too big for Pandas 3037
# year too big for Pandas 3037
# year too big for Pandas 3037
# year too big for Pandas 3045
# year too big for Pandas 2299
# year too big for Pandas 2299
# year too big for Pandas 2319
# year too big for Pandas 2339
# year too big for Pandas 2464
# year too big for Pandas 2484
# year too big for Pandas 2504
# year too big for Pandas 2629
# year too big for Pandas 3052
# year too big for Pandas 3052
# year too big for Pandas 3052
# year too big for Pandas 3021
# year too big for Pandas 3034
# year too big for Pandas 2376
# year too big for Pandas 2376
# year too big for Pandas 2396
# year too big for Pandas 2376
# year too big for Pandas 2550
# year too big for Pandas 3056
# year too big for Pandas 3030
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3023
# year too big for Pandas 3096
# year too big for Pandas 3096
# year too big for Pandas 3096
# year too big for Pandas 3096
# year too big for Pandas 3096
# year too big for Pandas 3038
# year too big for Pandas 3040
# year too big for Pandas 3101
# year too big for Pandas 3101
# year too big for Pandas 3111
# year too big for Pandas 3098
# year too big for Pandas 2282
# year too big for Pandas 2282
# year too big for Pandas 2312
# year too big for Pandas 2327
# year too big for Pandas 2342
# year too big for Pandas 3045
# year too big for Pandas 3046
# year too big for Pandas 3046
# year too big for Pandas 3040
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3113
# year too big for Pandas 3113
# year too big for Pandas 3113
# year too big for Pandas 3029
# year too big for Pandas 2274
# year too big for Pandas 2274
# year too big for Pandas 2288
# year too big for Pandas 2302
# year too big for Pandas 2316
# year too big for Pandas 2330
# year too big for Pandas 2344
# year too big for Pandas 2358
# year too big for Pandas 2372
# year too big for Pandas 2386
# year too big for Pandas 2400
# year too big for Pandas 2414
# year too big for Pandas 2428
# year too big for Pandas 2442
# year too big for Pandas 2456
# year too big for Pandas 2470
# year too big for Pandas 3038
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 3023
# year too big for Pandas 3023
# year too big for Pandas 3056
# year too big for Pandas 3061
# year too big for Pandas 3050
# year too big for Pandas 3020
# year too big for Pandas 3020
# year too big for Pandas 3036
# year too big for Pandas 3049
# year too big for Pandas 3029
# year too big for Pandas 3038
# year too big for Pandas 3053
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3020
# year too big for Pandas 3020
# year too big for Pandas 3020
# year too big for Pandas 4028
# year too big for Pandas 4028
# year too big for Pandas 3022
# year too big for Pandas 3022
# year too big for Pandas 3022
# year too big for Pandas 3020
# year too big for Pandas 3122
# year too big for Pandas 3128
# year too big for Pandas 3128
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3031
# year too big for Pandas 3051
# year too big for Pandas 2265
# year too big for Pandas 2265
# year too big for Pandas 2315
# year too big for Pandas 2325
# year too big for Pandas 3029
# year too big for Pandas 3058
# year too big for Pandas 3023
# year too big for Pandas 3054
# year too big for Pandas 3033
# year too big for Pandas 3054
# year too big for Pandas 3028
# year too big for Pandas 3020
# year too big for Pandas 3020
# year too big for Pandas 3040
# year too big for Pandas 3055
# year too big for Pandas 3029
# year too big for Pandas 3049
# year too big for Pandas 3049
# year too big for Pandas 3034
# year too big for Pandas 3034
# year too big for Pandas 3060
# year too big for Pandas 3046
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3041
# year too big for Pandas 3029
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3040
# year too big for Pandas 3029
# year too big for Pandas 3050
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3040
# year too big for Pandas 3015
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3050
# year too big for Pandas 3045
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3051
# year too big for Pandas 3051
# year too big for Pandas 3060
# year too big for Pandas 3039
# year too big for Pandas 3051
# year too big for Pandas 3051
# year too big for Pandas 3051
# year too big for Pandas 3051
# year too big for Pandas 3028
# year too big for Pandas 2269
# year too big for Pandas 2269
# year too big for Pandas 2304
# year too big for Pandas 2319
# year too big for Pandas 4088
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3036
# year too big for Pandas 3061
# year too big for Pandas 3061
# year too big for Pandas 3061
# year too big for Pandas 3061
# year too big for Pandas 3061
# year too big for Pandas 3015
# year too big for Pandas 3015
# year too big for Pandas 3051
# year too big for Pandas 3031
# year too big for Pandas 2273
# year too big for Pandas 2283
# year too big for Pandas 2303
# year too big for Pandas 2283
# year too big for Pandas 2283
# year too big for Pandas 3043
# year too big for Pandas 3036
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 3042
# year too big for Pandas 2264
# year too big for Pandas 2264
# year too big for Pandas 2266
# year too big for Pandas 3021
# year too big for Pandas 3021
# year too big for Pandas 3025
# year too big for Pandas 3028
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 3057
# year too big for Pandas 3057
# year too big for Pandas 3042
# year too big for Pandas 3019
# year too big for Pandas 3039
# year too big for Pandas 3039
# year too big for Pandas 4046
# year too big for Pandas 3020
# year too big for Pandas 3020
# year too big for Pandas 3043
# year too big for Pandas 3062
# year too big for Pandas 3062
# year too big for Pandas 3047
# year too big for Pandas 3052
# year too big for Pandas 3014
# year too big for Pandas 3032
# year too big for Pandas 3047
# year too big for Pandas 3039
# year too big for Pandas 3039
# year too big for Pandas 3050
# year too big for Pandas 3050
# year too big for Pandas 3033
# year too big for Pandas 3024
# year too big for Pandas 3039
# year too big for Pandas 3063
# year too big for Pandas 3029
# year too big for Pandas 3019
# year too big for Pandas 3049
# year too big for Pandas 3046
# year too big for Pandas 3035
# year too big for Pandas 3015
# year too big for Pandas 3015
# year too big for Pandas 3015
# year too big for Pandas 3042
# year too big for Pandas 3058
# year too big for Pandas 3134
# year too big for Pandas 3043
# year too big for Pandas 3048
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3053
# year too big for Pandas 3113
# year too big for Pandas 3102
# year too big for Pandas 3102
# year too big for Pandas 3122
# year too big for Pandas 3102
# year too big for Pandas 3054
# year too big for Pandas 3030
# year too big for Pandas 3030
# year too big for Pandas 2994
# year too big for Pandas 2996
# year too big for Pandas 2987
# year too big for Pandas 2998
# year too big for Pandas 3002
# year too big for Pandas 3002
# year too big for Pandas 3002
# year too big for Pandas 2993
# year too big for Pandas 2994
# year too big for Pandas 2994
# year too big for Pandas 2994
# year too big for Pandas 2994
# year too big for Pandas 3040
# year too big for Pandas 3102
# year too big for Pandas 3038
# year too big for Pandas 3104
# year too big for Pandas 3023
# year too big for Pandas 3056
# year too big for Pandas 2515
# year too big for Pandas 2515
# year too big for Pandas 2543
# year too big for Pandas 3054
# year too big for Pandas 3054
# year too big for Pandas 3054
# year too big for Pandas 3054
# year too big for Pandas 3054
# year too big for Pandas 3054
# year too big for Pandas 3054
# year too big for Pandas 3054
# year too big for Pandas 3054
# year too big for Pandas 3039
# year too big for Pandas 3039
# year too big for Pandas 3054
# year too big for Pandas 2277
# year too big for Pandas 5204
# year too big for Pandas 3127
# year too big for Pandas 3122
# year too big for Pandas 3122
# year too big for Pandas 3132
# year too big for Pandas 3132
# year too big for Pandas 3132
# year too big for Pandas 3127
# year too big for Pandas 3027
# year too big for Pandas 3027
# year too big for Pandas 3052
# year too big for Pandas 3052
# year too big for Pandas 3072
# year too big for Pandas 3122
# year too big for Pandas 2992
# year too big for Pandas 2325
# year too big for Pandas 2262
# year too big for Pandas 3015
# year too big for Pandas 3025
# year too big for Pandas 3045
# year too big for Pandas 3035
# year too big for Pandas 3096
# year too big for Pandas 3101
# year too big for Pandas 3101
# year too big for Pandas 2288
# year too big for Pandas 2288
# year too big for Pandas 2287
# year too big for Pandas 3016
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 3045
# year too big for Pandas 2947
# year too big for Pandas 2947
# year too big for Pandas 2947
# year too big for Pandas 2948
# year too big for Pandas 2947
# year too big for Pandas 2947
# year too big for Pandas 2947
# year too big for Pandas 2467
# year too big for Pandas 2467
# year too big for Pandas 2693
# year too big for Pandas 2693
# year too big for Pandas 2543
# year too big for Pandas 2443
# year too big for Pandas 2443
# year too big for Pandas 2443
# year too big for Pandas 2273
# year too big for Pandas 2273
# year too big for Pandas 2573
# year too big for Pandas 2288
# year too big for Pandas 2288
# year too big for Pandas 2788
# year too big for Pandas 3138
# year too big for Pandas 2637
# year too big for Pandas 2736
# year too big for Pandas 2743
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2637
# year too big for Pandas 2357
# year too big for Pandas 2357
# year too big for Pandas 2492
# year too big for Pandas 2627
# year too big for Pandas 2423
# year too big for Pandas 2423
# year too big for Pandas 2263
# year too big for Pandas 2413
# year too big for Pandas 2303
# year too big for Pandas 2302
# year too big for Pandas 2802
# year too big for Pandas 2803
# year too big for Pandas 2782
# year too big for Pandas 2772
# year too big for Pandas 2622
# year too big for Pandas 2575
# year too big for Pandas 2375
# year too big for Pandas 2375
# year too big for Pandas 2494
# year too big for Pandas 4949
# year too big for Pandas 5649
# year too big for Pandas 4649
# year too big for Pandas 2479
# year too big for Pandas 2479
# year too big for Pandas 3564
# year too big for Pandas 2300
# year too big for Pandas 2370
# year too big for Pandas 2300
# year too big for Pandas 2440
# year too big for Pandas 2440
# year too big for Pandas 2440
# year too big for Pandas 2359
# year too big for Pandas 2757
# year too big for Pandas 2359
# year too big for Pandas 2558
# year too big for Pandas 2976
# year too big for Pandas 2956
# year too big for Pandas 2429
# year too big for Pandas 2289
# year too big for Pandas 2289
# year too big for Pandas 2614
# year too big for Pandas 2799
# year too big for Pandas 2984
# year too big for Pandas 2799
# year too big for Pandas 2290
# year too big for Pandas 2290
# year too big for Pandas 2340
# year too big for Pandas 2390
# year too big for Pandas 2559
# year too big for Pandas 2559
# year too big for Pandas 2859
# year too big for Pandas 2935
# year too big for Pandas 2338
# year too big for Pandas 2338
# year too big for Pandas 2322
# year too big for Pandas 2322
# year too big for Pandas 2352
# year too big for Pandas 2417
# year too big for Pandas 2372
# year too big for Pandas 2372
# year too big for Pandas 2467
# year too big for Pandas 2447
# year too big for Pandas 2278
# year too big for Pandas 2947
# year too big for Pandas 2967
# year too big for Pandas 4012
# year too big for Pandas 2362
# year too big for Pandas 2441
# year too big for Pandas 2441
# year too big for Pandas 2274
# year too big for Pandas 2274
# year too big for Pandas 2374
# year too big for Pandas 2324
# year too big for Pandas 2419
# year too big for Pandas 2469
# year too big for Pandas 2514
# year too big for Pandas 2473
# year too big for Pandas 2512
# year too big for Pandas 2537
# year too big for Pandas 2537
# year too big for Pandas 2467
# year too big for Pandas 2417
# year too big for Pandas 2272
# year too big for Pandas 2272
# year too big for Pandas 2372
# year too big for Pandas 2322
# year too big for Pandas 2361
# year too big for Pandas 2261
# year too big for Pandas 2261
# year too big for Pandas 2461
# year too big for Pandas 2379
# year too big for Pandas 2274
# year too big for Pandas 2274
# year too big for Pandas 2481
# year too big for Pandas 2481
# year too big for Pandas 2269
# year too big for Pandas 2269
# year too big for Pandas 2267
# year too big for Pandas 2286
# year too big for Pandas 2286
# year too big for Pandas 2470
# year too big for Pandas 2470
# year too big for Pandas 2470
# year too big for Pandas 2386
# year too big for Pandas 2386
# year too big for Pandas 2586
# year too big for Pandas 2786
# year too big for Pandas 2998
# year too big for Pandas 2303
# year too big for Pandas 2303
# year too big for Pandas 2303
# year too big for Pandas 2367
# year too big for Pandas 2473
# year too big for Pandas 2473
# year too big for Pandas 3973
# year too big for Pandas 3473
# year too big for Pandas 2973
# year too big for Pandas 4573
# year too big for Pandas 5073
# year too big for Pandas 4073
# year too big for Pandas 4023
# year too big for Pandas 5623
# year too big for Pandas 5123
# year too big for Pandas 6123
# year too big for Pandas 6623
# year too big for Pandas 7123
# year too big for Pandas 7173
# year too big for Pandas 2462
# year too big for Pandas 2462
# year too big for Pandas 2462
# year too big for Pandas 2962
# year too big for Pandas 2263
# year too big for Pandas 2263
# year too big for Pandas 2444
# year too big for Pandas 2444
# year too big for Pandas 2494
# year too big for Pandas 2494
# year too big for Pandas 2279
# year too big for Pandas 2287
# year too big for Pandas 2946
# year too big for Pandas 2966
# year too big for Pandas 2946
# year too big for Pandas 2966
# year too big for Pandas 2966
# year too big for Pandas 2288
# year too big for Pandas 2288
# year too big for Pandas 2461
# year too big for Pandas 2401
# year too big for Pandas 2281
# year too big for Pandas 2341
# year too big for Pandas 2281
# year too big for Pandas 2280
# year too big for Pandas 2408
# year too big for Pandas 2408
# year too big for Pandas 2408
# year too big for Pandas 2262
# year too big for Pandas 2262
# year too big for Pandas 2400
# year too big for Pandas 2538
# year too big for Pandas 2962
# year too big for Pandas 2952
# year too big for Pandas 2814
# year too big for Pandas 2676
# year too big for Pandas 2478
# year too big for Pandas 2262
# year too big for Pandas 2272
# year too big for Pandas 2262
# year too big for Pandas 2292
# year too big for Pandas 2411
# year too big for Pandas 2311
# year too big for Pandas 2311
# year too big for Pandas 2454
# year too big for Pandas 2754
# year too big for Pandas 2654
# year too big for Pandas 2454
# year too big for Pandas 2854
# year too big for Pandas 2731
# year too big for Pandas 2731
# year too big for Pandas 2876
# year too big for Pandas 2475
# year too big for Pandas 2475
# year too big for Pandas 2475
# year too big for Pandas 2475
# year too big for Pandas 2475
# year too big for Pandas 2475
# year too big for Pandas 2270
# year too big for Pandas 2381
# year too big for Pandas 2303
# year too big for Pandas 2329
# year too big for Pandas 2381
# year too big for Pandas 2381
# year too big for Pandas 2383
# year too big for Pandas 2408
# year too big for Pandas 2383
# year too big for Pandas 2608
# year too big for Pandas 2408
# year too big for Pandas 2853
# year too big for Pandas 2618
# year too big for Pandas 2833
# year too big for Pandas 2608
# year too big for Pandas 2868
# year too big for Pandas 2918
# year too big for Pandas 2968
# year too big for Pandas 2968
# year too big for Pandas 2468
# year too big for Pandas 2968
# year too big for Pandas 2468
# year too big for Pandas 2472
# year too big for Pandas 2472
# year too big for Pandas 2282
# year too big for Pandas 2274
# year too big for Pandas 2274
# year too big for Pandas 2304
# year too big for Pandas 2364
# year too big for Pandas 2334
# year too big for Pandas 2394
# year too big for Pandas 2276
# year too big for Pandas 2292
# year too big for Pandas 2292
# year too big for Pandas 2362
# year too big for Pandas 2422
# year too big for Pandas 2469
# year too big for Pandas 2281
# year too big for Pandas 2391
# year too big for Pandas 2281
# year too big for Pandas 2336
# year too big for Pandas 2681
# year too big for Pandas 2634
# year too big for Pandas 2587
# year too big for Pandas 2540
# year too big for Pandas 2493
# year too big for Pandas 2446
# year too big for Pandas 2273
# year too big for Pandas 2272
# year too big for Pandas 2272
# year too big for Pandas 2312
# year too big for Pandas 2332
# year too big for Pandas 2292
# year too big for Pandas 2352
# year too big for Pandas 2372
# year too big for Pandas 2332
# year too big for Pandas 2392
# year too big for Pandas 2412
# year too big for Pandas 2432
# year too big for Pandas 2452
# year too big for Pandas 2472
# year too big for Pandas 2492
# year too big for Pandas 2512
# year too big for Pandas 2532
# year too big for Pandas 2384
# year too big for Pandas 2370
# year too big for Pandas 2361
# year too big for Pandas 2361
# year too big for Pandas 2361
# year too big for Pandas 2761
# year too big for Pandas 2262
# year too big for Pandas 2262
# year too big for Pandas 2287
# year too big for Pandas 2386
# year too big for Pandas 2476
# year too big for Pandas 2536
# year too big for Pandas 2626
# year too big for Pandas 2272
# year too big for Pandas 2302
# year too big for Pandas 2656
# year too big for Pandas 2683
# year too big for Pandas 2656
# year too big for Pandas 2266
# year too big for Pandas 2265
# year too big for Pandas 2266
# year too big for Pandas 2266
# year too big for Pandas 2286
# year too big for Pandas 2261
# year too big for Pandas 2261
# year too big for Pandas 2411
# year too big for Pandas 2336
# year too big for Pandas 2486
# year too big for Pandas 2464
# year too big for Pandas 2464
# year too big for Pandas 2264
# year too big for Pandas 2276
# year too big for Pandas 2264
# year too big for Pandas 2272
# year too big for Pandas 2276
# year too big for Pandas 2282
# year too big for Pandas 2316
# year too big for Pandas 2368
# year too big for Pandas 2368
# year too big for Pandas 2568
# year too big for Pandas 2968
# year too big for Pandas 2768
# year too big for Pandas 3168
# year too big for Pandas 2332
# year too big for Pandas 2332
# year too big for Pandas 2332
# year too big for Pandas 2352
# year too big for Pandas 2372
# year too big for Pandas 2352
# year too big for Pandas 2356
# year too big for Pandas 2356
# year too big for Pandas 2473
# year too big for Pandas 2473
# year too big for Pandas 2473
# year too big for Pandas 2723
# year too big for Pandas 2473
# year too big for Pandas 2723
# year too big for Pandas 2973
# year too big for Pandas 2274
# year too big for Pandas 2274
# year too big for Pandas 2266
# year too big for Pandas 2566
# year too big for Pandas 2266
# year too big for Pandas 2866
# year too big for Pandas 2309
# year too big for Pandas 2270
# year too big for Pandas 2270
# year too big for Pandas 2333
# year too big for Pandas 2333
# year too big for Pandas 2408
# year too big for Pandas 2308
# year too big for Pandas 2283
# year too big for Pandas 2303
# year too big for Pandas 2283
# year too big for Pandas 2317
# year too big for Pandas 2275
# year too big for Pandas 2275
# year too big for Pandas 2475
# year too big for Pandas 2375
# year too big for Pandas 2295
# year too big for Pandas 2315
# year too big for Pandas 2275
# year too big for Pandas 2275
# year too big for Pandas 2284
# year too big for Pandas 2284
# year too big for Pandas 2384
# year too big for Pandas 2349
# year too big for Pandas 2538
# year too big for Pandas 2558
# year too big for Pandas 2538
# year too big for Pandas 3108
# year too big for Pandas 2483
# year too big for Pandas 2483
# year too big for Pandas 2983
# year too big for Pandas 3983
# year too big for Pandas 3483
# year too big for Pandas 2341
# year too big for Pandas 2386
# year too big for Pandas 2296
# year too big for Pandas 2296
# year too big for Pandas 2262
# year too big for Pandas 2262
# year too big for Pandas 2269
# year too big for Pandas 3043
# year too big for Pandas 3044
# year too big for Pandas 3044
# year too big for Pandas 3026
# year too big for Pandas 3046
# year too big for Pandas 3066
# year too big for Pandas 3026
# year too big for Pandas 3081
# year too big for Pandas 3081
# year too big for Pandas 3022
# year too big for Pandas 3022
# year too big for Pandas 3019
# year too big for Pandas 3020
# year too big for Pandas 5015
# year too big for Pandas 3014
# year too big for Pandas 3026
# year too big for Pandas 3026
# year too big for Pandas 2332
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 2335
# year too big for Pandas 3117

# %%
sentenceDS = pd.DataFrame(data=sentence_database, columns=first_row)
sentenceDS['ConvictDate'] = pd.to_datetime(sentenceDS['ConvictDate'])
sentenceDS['StartDate'] = pd.to_datetime(sentenceDS['StartDate'])
sentenceDS['EndDate'] = pd.to_datetime(sentenceDS['EndDate'])
sentenceDS.ConvictDate=sentenceDS.ConvictDate.dt.strftime('%Y')

# %%
pt = pd.pivot_table(sentenceDS, values=["DOCNum"], index=["ConvictDate"], aggfunc="count")
pt.plot(kind="line",).legend()
